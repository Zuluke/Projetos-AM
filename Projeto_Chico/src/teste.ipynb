# %%
    # @staticmethod
    # def compute_kernel(X_l, X_k, s):
    #     return np.exp(-0.5 * np.sum(s * (X_l - X_k )**2, axis=1))
    
    # def _update_U(self):
        
    #     ## Calculate kernel values
    #     U = np.zeros((self._n, self._n_clusters))
        
    #     K = np.zeros((self._n, self._n_clusters))
    #     for k in range(self._n):
    #         for i in range(self._n_clusters):
    #             K[k, i] = self.compute_kernel(self._X[k, :], self._G[i, :], self._s)
        
    #     for k in range(self._n):
    #         for i in range(self._n_clusters):
    #             # Calculate the denominator
    #             sum_term = 0
    #             for h in range(self._n_clusters):
    #                 ratio += (2 - 2 * K[k, i]) / (2 - 2 * K[k, h])
    #                 sum_term += ratio
    #             U[k, i] = 1 / sum_term
        
    #     self._U = U

# %%
from sklearn import datasets

X = datasets.load_breast_cancer().data

# %%
from kfcm_k_w1 import KFCM_K_W1
import numpy as np
from sklearn import datasets

X = datasets.load_breast_cancer().data

n_clusters = 40
m = 1.3
max_iter = 1000
tol = 1e-5
random_state = 0;

kfcm = KFCM_K_W1(n_clusters=n_clusters, m=m, n_iter=max_iter, epsilon=tol, random_state=random_state)
kfcm.fit(X)
# Out:
# Iteration 1: J = 53.56130623599693
# Iteration 2: J = 20.381488633056385
# Iteration 3: J = 16.48895673374107
# Iteration 4: J = 16.319595283595195
# Iteration 5: J = 16.397891535502247
# Iteration 6: J = 16.39393484347165
# Iteration 7: J = 16.36157332502819
# Iteration 8: J = 16.29450250104527
# Iteration 9: J = 16.18693588281453
# Iteration 10: J = 16.030748957166328
# Iteration 11: J = 15.830380829627533
# Iteration 12: J = 15.60413855510979
# Iteration 13: J = 15.383980157581295
# Iteration 14: J = 15.200157912999288
# Iteration 15: J = 15.059148631644732
# Iteration 16: J = 14.963088916375579
# Iteration 17: J = 14.88838752511965
# Iteration 18: J = 14.796392170210693
# Iteration 19: J = 14.667519595191095
# Iteration 20: J = 14.517136288754314
# Iteration 21: J = 14.461100517575726
# Iteration 22: J = 14.4777428339893
# Iteration 23: J = 14.46371699821266
# Iteration 24: J = 14.430259863363831
# Iteration 25: J = 14.400140040157538
# Iteration 26: J = 14.38666549223127
# ...
